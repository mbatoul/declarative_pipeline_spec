# %%
import yaml
from pprint import pprint

# %%
with open("pipeline.yml", "r") as f:
    pipeline = yaml.load(f,  Loader=yaml.FullLoader)

# %%
pprint(pipeline)
# Out:
# {'global': {'errors': ['neg_mean_absolute_error',
#                        'neg_root_mean_squared_error'],
#             'target': 'count'},
#  'steps': [{'kwargs': {'as_frame': True, 'version': 2},
#             'path': 'sklearn.datasets.fetch_openml',
#             'type': 'downloader'},
#            {'args': {'func': [{'path': 'custom.collapse_heavy_rain_into_rain',
#                                'type': 'function'}]},
#             'name': 'Collapse heavy_rain weather category into rain',
#             'path': 'sklearn.preprocessing.FunctionTransformer',
#             'type': 'preprocessor'},
#            {'kwargs': {'func': [{'path': 'custom.rescale_count',
#                                  'type': 'function'}]},
#             'name': 'Rescale count',
#             'path': 'sklearn.preprocessing.FunctionTransformer',
#             'type': 'preprocessor'},
#            {'kwargs': {'gap': 48,
#                        'max_train_size': 10000,
# ...
